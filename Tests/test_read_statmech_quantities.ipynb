# %%
import PyKorg
# Out:
# C:\Users\User5\Desktop\Jupyter Notebook\PyKorg\read_statmech_quantities.py:143: RuntimeWarning: divide by zero encountered in log
#   out[spec] = construct_spline(np.log(Ts),Us / total_g_ns, extrapolate=True)

# %%
PyKorg.read_statmech_quantities.ionization_energies
# Out:
# {'1': ['13.5984', '-1.000', '-1.000'],
#  '2': ['24.5874', '54.418', '-1.000'],
#  '3': ['5.3917', '75.640', '122.454'],
#  '4': ['9.3227', '18.211', '153.896'],
#  '5': ['8.2980', '25.155', '37.931'],
#  '6': ['11.2603', '24.385', '47.888'],
#  '7': ['14.5341', '29.601', '47.445'],
#  '8': ['13.6181', '35.121', '54.936'],
#  '9': ['17.4228', '34.971', '62.708'],
#  '10': ['21.5645', '40.963', '63.423'],
#  '11': ['5.1391', '47.286', '71.620'],
#  '12': ['7.6462', '15.035', '80.144'],
#  '13': ['5.9858', '18.829', '28.448'],
#  '14': ['8.1517', '16.346', '33.493'],
#  '15': ['10.4867', '19.769', '30.203'],
#  '16': ['10.3600', '23.338', '34.856'],
#  '17': ['12.9676', '23.814', '39.800'],
#  '18': ['15.7596', '27.630', '40.735'],
#  '19': ['4.3407', '31.625', '45.803'],
#  '20': ['6.1132', '11.872', '50.913'],
#  '21': ['6.5615', '12.800', '24.757'],
#  '22': ['6.8281', '13.575', '27.492'],
#  '23': ['6.7462', '14.620', '29.311'],
#  '24': ['6.7665', '16.486', '30.960'],
# ...

# %%
PyKorg.read_statmech_quantities.default_partition_funcs
# Out:
# {Species(formula=[0, 0, 0, 0, 7, 8], charge=0): CubicSpline(t=[-11.51292546  -9.21034037  -6.90775528  -4.60517019  -2.30258509
#    -1.89711998  -1.60943791  -1.2039728   -0.69314718  -0.35667494
#     0.           0.26236426   0.53062825   0.69314718   1.09861229
#     1.60943791   1.94591015   2.30258509   2.7080502    2.99573227
#     3.40119738   3.91202301   4.24849524   4.60517019   4.86753445
#     5.13579844   5.29831737   5.52146092   5.70378247   6.2146081
#     6.55108034   6.90775528   7.31322039   7.60090246   8.00636757
#     8.29404964   8.51719319   8.69951475   8.85366543   8.98719682
#     9.10497986   9.21034037], u=[-3.27982000e+09 -3.27981999e+08 -3.27981990e+07 -3.27981900e+06
#   -3.27978000e+05 -2.18651000e+05 -1.63987000e+05 -1.09322000e+05
#   -6.55909000e+04 -4.68487000e+04 -3.27920000e+04 -2.52229000e+04
#   -1.92862000e+04 -1.63921000e+04 -1.09253000e+04 -6.55175000e+03
#   -4.67727000e+03 -3.27135000e+03 -2.17776000e+03 -1.63092000e+03
# ...

# %%
PyKorg.read_statmech_quantities.default_equilibrium_constants
# Out:
# {Species(formula=[0, 0, 0, 0, 7, 8], charge=0): CubicSpline(t=[-11.51292546  -9.21034037  -6.90775528  -4.60517019  -2.30258509
#    -1.89711998  -1.60943791  -1.2039728   -0.69314718  -0.35667494
#     0.           0.26236426   0.53062825   0.69314718   1.09861229
#     1.60943791   1.94591015   2.30258509   2.7080502    2.99573227
#     3.40119738   3.91202301   4.24849524   4.60517019   4.86753445
#     5.13579844   5.29831737   5.52146092   5.70378247   6.2146081
#     6.55108034   6.90775528   7.31322039   7.60090246   8.00636757
#     8.29404964   8.51719319   8.69951475   8.85366543   8.98719682
#     9.10497986   9.21034037], u=[-3.27982000e+09 -3.27981999e+08 -3.27981990e+07 -3.27981900e+06
#   -3.27978000e+05 -2.18651000e+05 -1.63987000e+05 -1.09322000e+05
#   -6.55909000e+04 -4.68487000e+04 -3.27920000e+04 -2.52229000e+04
#   -1.92862000e+04 -1.63921000e+04 -1.09253000e+04 -6.55175000e+03
#   -4.67727000e+03 -3.27135000e+03 -2.17776000e+03 -1.63092000e+03
# ...

# %%
PyKorg.read_statmech_quantities.default_partition_funcs == PyKorg.read_statmech_quantities.default_equilibrium_constants
# Out:
# False

# %%
PyKorg.read_statmech_quantities.default_partition_funcs[PyKorg.species.Species(PyKorg.species.Formula([7, 8]), charge=0)]
# Out:
# CubicSpline(t=[-11.51292546  -9.21034037  -6.90775528  -4.60517019  -2.30258509
#   -1.89711998  -1.60943791  -1.2039728   -0.69314718  -0.35667494
#    0.           0.26236426   0.53062825   0.69314718   1.09861229
#    1.60943791   1.94591015   2.30258509   2.7080502    2.99573227
#    3.40119738   3.91202301   4.24849524   4.60517019   4.86753445
#    5.13579844   5.29831737   5.52146092   5.70378247   6.2146081
#    6.55108034   6.90775528   7.31322039   7.60090246   8.00636757
#    8.29404964   8.51719319   8.69951475   8.85366543   8.98719682
# ...

# %%
PyKorg.read_statmech_quantities.default_equilibrium_constants[PyKorg.species.Species(PyKorg.species.Formula([7, 8]), charge=0)]
# Out:
# CubicSpline(t=[-11.51292546  -9.21034037  -6.90775528  -4.60517019  -2.30258509
#   -1.89711998  -1.60943791  -1.2039728   -0.69314718  -0.35667494
#    0.           0.26236426   0.53062825   0.69314718   1.09861229
#    1.60943791   1.94591015   2.30258509   2.7080502    2.99573227
#    3.40119738   3.91202301   4.24849524   4.60517019   4.86753445
#    5.13579844   5.29831737   5.52146092   5.70378247   6.2146081
#    6.55108034   6.90775528   7.31322039   7.60090246   8.00636757
#    8.29404964   8.51719319   8.69951475   8.85366543   8.98719682
#    9.10497986   9.21034037], u=[-3.27982000e+09 -3.27981999e+08 -3.27981990e+07 -3.27981900e+06
#  -3.27978000e+05 -2.18651000e+05 -1.63987000e+05 -1.09322000e+05
#  -6.55909000e+04 -4.68487000e+04 -3.27920000e+04 -2.52229000e+04
#  -1.92862000e+04 -1.63921000e+04 -1.09253000e+04 -6.55175000e+03
#  -4.67727000e+03 -3.27135000e+03 -2.17776000e+03 -1.63092000e+03
#  -1.08399000e+03 -6.46343000e+02 -4.58711000e+02 -3.17927000e+02
# ...
